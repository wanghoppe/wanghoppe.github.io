# %% [markdown]
# ## Heap
#
# - Java
# ```java
# //Heap
# PriorityQueue<Integer> q = new PriorityQueue<Integer>();
# q.poll();
# q.offer();
# q.peek();
# q.size();
# //
# //Queue
# Deque<Integer> q = new LinkedList(<Integer>);
# q.offer();
# q.peek();
# q.poll();
# //
# //Stack
# Deque<Integer> stk = new LinkedList(<Integer>);
# stk.push();
# stk.peekLast();
# stk.pop();
# //
# //Hash table
# Map<String, String> m = new HashMap<String, String>();
# m.put(k,v);
# m.get();
# m.remove();
# m.containsKey(k);
# m.replace();
# m.keySet();
# m.values();
# //
# // Set
# Set<String, String> s = new HashSet<String, String>();
# s.add();
# s.remove();
# s.contains()
# ```
# - Python
# ```python
# # Heap
# import heapq
# heapq.heapify
# heapq.heappop
# heapq.nlargest
# heapq.heappush
# heapq._heappop_max
# heapq._heappop_max
# #
# # Queue
# q = [1,2,3]
# q.append(4)
# q.pop(0)
# #
# # Stack
# s.append('11')
# s.pop()
# ```
