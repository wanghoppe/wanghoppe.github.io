# %% [markdown]
# # Linear‐Time Selection
# ## Randomized Selection (Algorithm)
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
